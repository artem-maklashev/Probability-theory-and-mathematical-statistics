# %% [markdown]
# ### Seminar9

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
from scipy import stats as st

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Ex001

# %% [markdown]
# ![Снимок экрана 2023-09-03 095957.png](data:image/png;base64,...)

# %%
x1= np.array([30,30,40, 40])
y1= np.array([37, 47, 50, 60])

# %%
model = LinearRegression()

# %%
x1 = x1.reshape(-1, 1)

# %%
model.fit(x1, y1)
# Out:
# LinearRegression()

# %%
R_determ_1 = model.score(x1, y1)
print('coefficient of determination:', R_determ_1)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.6282527881040892
# intercept: 3.0
# slope: [1.3]

# %%
plt.scatter(x1, y1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('r= 0.6282')
plt.plot(x1, 3 + 1.3*x1)

# %%
x2= np.array([30,30,40, 40, 20, 20, 50, 50])
y2= np.array([37, 47, 50, 60, 25, 35, 62, 72])

# %%
x2 = x2.reshape(-1, 1)

# %%
model.fit(x2, y2)
# Out:
# LinearRegression()

# %%
R_determ_2 = model.score(x2, y2)
print('coefficient of determination:', R_determ_2)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.8846950517836594
# intercept: 5.1000000000000085
# slope: [1.24]

# %%
plt.scatter(x2, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('r = 0.8826')
plt.plot(x2, 5.1 + 1.24*x2)

# %%
x3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])
x3 = x3.reshape(-1, 1)
model.fit(x3, y3)
# Out:
# LinearRegression()

# %%
R_determ_3 = model.score(x3, y3)
print('coefficient of determination:', R_determ_3)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.9459101071621309
# intercept: 5.600000000000016
# slope: [1.22571429]

# %%
plt.scatter(x3, y3)
plt.xlabel('x')
plt.ylabel('y')
plt.title('r=0.9424')
plt.plot(x3, 5.6 + 1.226*x3)

# %% [markdown]
# ### Ex002

# %% [markdown]
# ![Снимок экрана 2023-09-03 100133.png](data:image/png;base64,...)

# %%
x0= np.array([ 10, 8, 13, 9, 11, 14, 6, 4, 12, 7.5, 15, 16, 18])
y0 = np.array([ 9.14, 8.14, 8.74,8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 6.5, 5, 2.9])

x1 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y1 = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])

x2= np.array([10,8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y2 = np.array([9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])

x3= np.array([10,8, 13, 9,11,14, 6,4,12, 7,5 ])
y3 = np.array([7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])

x4 = np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8])
y4 = np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25,12.5, 5.56, 7.91, 6.89])

# %%
x1 = x1.reshape(-1, 1)
model.fit(x1, y1)
# Out:
# LinearRegression()

# %%
R_determ_1 = model.score(x1, y1)
print('coefficient of determination:', R_determ_1)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.6665424595087748
# intercept: 3.0000909090909094
# slope: [0.50009091]

# %%
plt.scatter(x1, y1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('r=0.6665')
plt.plot(x1, 3.0 + 0.500*x1)

# %%
y1_res = 3.0 + 0.500*x1

# %%
y1_rest = y1_res.reshape(1, -1)

# %%
y1_res, y1_rest
# Out:
# (array([[ 8. ],
#         [ 7. ],
#         [ 9.5],
#         [ 7.5],
#         [ 8.5],
#         [10. ],
#         [ 6. ],
#         [ 5. ],
#         [ 9. ],
#         [ 6.5],
#         [ 5.5]]),
#  array([[ 8. ,  7. ,  9.5,  7.5,  8.5, 10. ,  6. ,  5. ,  9. ,  6.5,  5.5]]))

# %%
res = y1 - y1_rest
print(res)
# Out:
# [[ 0.04 -0.05 -1.92  1.31 -0.17 -0.04  1.24 -0.74  1.84 -1.68  0.18]]

# %%
plt.scatter(x1, res)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
st.shapiro(res)
# Out:
# ShapiroResult(statistic=0.9420998096466064, pvalue=0.545490026473999)

# %%
plt.scatter(y1_res, res)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Ex003

# %% [markdown]
# ![Снимок экрана 2023-09-03 100142.png](data:image/png;base64,...)

# %% [markdown]
# ### Ex004

# %% [markdown]
# ![Снимок экрана 2023-09-03 100150.png](data:image/png;base64,...)

# %% [markdown]
# ### Ex005

# %% [markdown]
# ![Снимок экрана 2023-09-03 100157.png](data:image/png;base64,...)

# %%
N = len(x1)
N
# Out:
# 11

# %%
ddf = N - 2
ddf
# Out:
# 9

# %%
y_pred = model.predict(x1)
y_pred
# Out:
# array([ 8.001     ,  7.00081818,  9.50127273,  7.50090909,  8.50109091,
#        10.00136364,  6.00063636,  5.00045455,  9.00118182,  6.50072727,
#         5.50054545])

# %%
y1, y_pred
# Out:
# (array([ 8.04,  6.95,  7.58,  8.81,  8.33,  9.96,  7.24,  4.26, 10.84,
#          4.82,  5.68]),
#  array([ 8.001     ,  7.00081818,  9.50127273,  7.50090909,  8.50109091,
#         10.00136364,  6.00063636,  5.00045455,  9.00118182,  6.50072727,
#          5.50054545]))

# %%
ssf = sum((y_pred - np.mean(x1))**2)
ssf
# Out:
# 52.23000999999996

# %%
sso = np.sum((x1 - y_pred)**2)
sso
# Out:
# 1784.5301099999995

# %%
F_test = (ssf/(1))/(sso/ddf)
F_test
# Out:
# 0.26341393029227156

# %%
st.f.ppf(1 - 0.05, 1, 9)
# Out:
# 5.117355029199227
